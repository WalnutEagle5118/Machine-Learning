# %% [markdown]
# <a href="https://colab.research.google.com/github/WalnutEagle5118/Machine-Learning/blob/main/AIML_EXPT_3_TEMEB233.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from skimage.io import imread , imshow

# %%
image1 = imread(r'https://raw.githubusercontent.com/WalnutEagle5118/Colab-College-Data/0dd0ebf3e2a18e95df60876b0a9f1f797364b730/R.jpg?token=GHSAT0AAAAAABR7WXMCXXYTNHVLQBTJ726IYRB57XQ')

# %%
imshow(image1)

# %%
image2 = imread(r'https://raw.githubusercontent.com/WalnutEagle5118/Colab-College-Data/0dd0ebf3e2a18e95df60876b0a9f1f797364b730/R.jpg?token=GHSAT0AAAAAABR7WXMCXXYTNHVLQBTJ726IYRB57XQ',as_gray=True)

# %%
print(image1.shape)
# Out:
# (1080, 1920, 3)

# %%
print(image2.shape)
# Out:
# (1080, 1920)

# %%
pixel_feat1 = np.reshape(image2, (1080*1920))

# %%
pixel_feat1
# Out:
# array([0.01538863, 0.01538863, 0.01538863, ..., 0.04255686, 0.05432157,
#        0.06216471])

# %%
pixel_feat2 = np.reshape(image1, (1080*1920*3))

# %%
pixel_feat2
# Out:
# array([ 5,  4,  0, ..., 17, 16, 11], dtype=uint8)

# %%
from skimage.filters import prewitt_h,prewitt_v
edges_prewitt_horizontal = prewitt_h(image2)
imshow(edges_prewitt_horizontal, cmap='gray');

# %%
edges_prewitt_vertical = prewitt_v(image2)
imshow(edges_prewitt_vertical, cmap='gray');

# %%
from skimage.exposure import histogram
hist, hist_centers = histogram(image2)
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(image2, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('histogram of gray values')
# Out:
# Text(0.5, 1.0, 'histogram of gray values')

# %%
from skimage.exposure import histogram
hist, hist_centers = histogram(image1)
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(image1, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('histogram of color channel')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
# Text(0.5, 1.0, 'histogram of color channel')
